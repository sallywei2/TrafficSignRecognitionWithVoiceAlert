# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.24.3-cp38-cp38-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#       --------------------------------------- 0.2/14.9 MB 4.1 MB/s eta 0:00:04
#      - -------------------------------------- 0.7/14.9 MB 10.4 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.6/14.9 MB 11.5 MB/s eta 0:00:02
#      --------- ------------------------------ 3.5/14.9 MB 18.5 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.9/14.9 MB 20.8 MB/s eta 0:00:01
#      ------------------ --------------------- 6.8/14.9 MB 25.6 MB/s eta 0:00:01
#      ----------------------- ---------------- 8.6/14.9 MB 27.4 MB/s eta 0:00:01
#      -------------------------- ------------- 9.7/14.9 MB 28.2 MB/s eta 0:00:01
#      -------------------------- ------------ 10.0/14.9 MB 23.7 MB/s eta 0:00:01
#      ---------------------------------- ---- 13.1/14.9 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------  14.9/14.9 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------- 14.9/14.9 MB 32.7 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-1.24.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install Keras
# Out:
# Collecting KerasNote: you may need to restart the kernel to use updated packages.
#
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Installing collected packages: Keras
# Successfully installed Keras-2.12.0

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Downloading tensorflow_intel-2.12.0-cp38-cp38-win_amd64.whl (272.8 MB)
#      ---------------------------------------- 0.0/272.8 MB ? eta -:--:--
#      ---------------------------------------- 0.2/272.8 MB 5.0 MB/s eta 0:00:56
#      --------------------------------------- 1.0/272.8 MB 13.1 MB/s eta 0:00:21
#      --------------------------------------- 2.5/272.8 MB 19.8 MB/s eta 0:00:14
#      --------------------------------------- 3.4/272.8 MB 19.8 MB/s eta 0:00:14
#       -------------------------------------- 4.1/272.8 MB 17.6 MB/s eta 0:00:16
#       -------------------------------------- 6.6/272.8 MB 24.9 MB/s eta 0:00:11
#      - ------------------------------------- 8.4/272.8 MB 25.4 MB/s eta 0:00:11
#      - ------------------------------------- 9.2/272.8 MB 24.5 MB/s eta 0:00:11
#      - ------------------------------------ 11.4/272.8 MB 31.2 MB/s eta 0:00:09
#      - ------------------------------------ 12.7/272.8 MB 32.8 MB/s eta 0:00:08
#      - ------------------------------------ 13.7/272.8 MB 31.1 MB/s eta 0:00:09
#      -- ----------------------------------- 15.5/272.8 MB 34.4 MB/s eta 0:00:08
#      -- ----------------------------------- 17.1/272.8 MB 32.7 MB/s eta 0:00:08
#      -- ----------------------------------- 18.5/272.8 MB 29.7 MB/s eta 0:00:09
#      -- ----------------------------------- 20.4/272.8 MB 32.8 MB/s eta 0:00:08
#      --- ---------------------------------- 22.0/272.8 MB 32.8 MB/s eta 0:00:08
#      ------------------------------------  270.5/272.8 MB 15.2 MB/s eta 0:00:01
#      ------------------------------------  271.2/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.1/272.8 MB 15.2 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------  272.8/272.8 MB 14.6 MB/s eta 0:00:01
#      -------------------------------------- 272.8/272.8 MB 4.3 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.0-cp38-cp38-win_amd64.whl (4.1 MB)
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------- ----------------------------- 1.1/4.1 MB 23.7 MB/s eta 0:00:01
#      ------------------ --------------------- 1.9/4.1 MB 20.3 MB/s eta 0:00:01
#      ------------------------- -------------- 2.7/4.1 MB 18.7 MB/s eta 0:00:01
#      -------------------------------- ------- 3.4/4.1 MB 19.5 MB/s eta 0:00:01
#      ---------------------------------------  4.1/4.1 MB 18.7 MB/s eta 0:00:01
#      ---------------------------------------- 4.1/4.1 MB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.8.tar.gz (1.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting wrapt<1.15,>=1.11.0
#   Downloading wrapt-1.14.1-cp38-cp38-win_amd64.whl (35 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp38-cp38-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ------------------------------ --------- 1.1/1.5 MB 24.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 18.9 MB/s eta 0:00:00
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#      ------- -------------------------------- 1.0/5.6 MB 33.4 MB/s eta 0:00:01
#      -------------- ------------------------- 2.1/5.6 MB 22.3 MB/s eta 0:00:01
#      -------------------- ------------------- 2.8/5.6 MB 22.6 MB/s eta 0:00:01
#      --------------------------- ------------ 3.9/5.6 MB 20.5 MB/s eta 0:00:01
#      -------------------------------- ------- 4.6/5.6 MB 19.5 MB/s eta 0:00:01
#      ---------------------------------------  5.6/5.6 MB 20.0 MB/s eta 0:00:01
#      ---------------------------------------- 5.6/5.6 MB 18.0 MB/s eta 0:00:00
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.5-cp38-cp38-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#      -- ------------------------------------- 1.0/14.7 MB 21.4 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.8/14.7 MB 23.5 MB/s eta 0:00:01
#      ------- -------------------------------- 2.7/14.7 MB 19.5 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.7/14.7 MB 21.4 MB/s eta 0:00:01
#      ------------ --------------------------- 4.6/14.7 MB 19.8 MB/s eta 0:00:01
#      -------------- ------------------------- 5.4/14.7 MB 20.2 MB/s eta 0:00:01
#      ---------------- ----------------------- 6.2/14.7 MB 19.9 MB/s eta 0:00:01
#      ------------------ --------------------- 6.8/14.7 MB 18.9 MB/s eta 0:00:01
#      ------------------- -------------------- 7.3/14.7 MB 17.9 MB/s eta 0:00:01
#      --------------------- ------------------ 8.0/14.7 MB 17.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 8.7/14.7 MB 17.4 MB/s eta 0:00:01
#      ------------------------- -------------- 9.2/14.7 MB 16.8 MB/s eta 0:00:01
#      ------------------------- -------------- 9.4/14.7 MB 15.5 MB/s eta 0:00:01
#      -------------------------- ------------ 10.1/14.7 MB 15.8 MB/s eta 0:00:01
#      ---------------------------- ---------- 10.9/14.7 MB 15.2 MB/s eta 0:00:01
#      ------------------------------- ------- 11.7/14.7 MB 14.9 MB/s eta 0:00:01
#      --------------------------------- ----- 12.6/14.7 MB 15.2 MB/s eta 0:00:01
#      ----------------------------------- --- 13.5/14.7 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  14.3/14.7 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  14.7/14.7 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------- 14.7/14.7 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.5.0)
# Requirement already satisfied: setuptools in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (66.0.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.22.4-cp38-cp38-win_amd64.whl (420 kB)
#      ---------------------------------------- 0.0/420.6 kB ? eta -:--:--
#      ------------------------------------- 420.6/420.6 kB 13.2 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.8.0-cp38-cp38-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#      ------------------ --------------------- 1.2/2.7 MB 26.1 MB/s eta 0:00:01
#      ------------------------------ --------- 2.0/2.7 MB 26.0 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 MB 21.1 MB/s eta 0:00:01
#      ---------------------------------------- 2.7/2.7 MB 18.8 MB/s eta 0:00:00
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: packaging in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Using cached tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Collecting ml-dtypes>=0.0.3
#   Downloading ml_dtypes-0.1.0-cp38-cp38-win_amd64.whl (120 kB)
#      ---------------------------------------- 0.0/120.2 kB ? eta -:--:--
#      -------------------------------------- 120.2/120.2 kB 7.3 MB/s eta 0:00:00
# Collecting scipy>=1.7
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#      ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#       --------------------------------------- 0.9/42.2 MB 28.7 MB/s eta 0:00:02
#      - -------------------------------------- 1.7/42.2 MB 21.8 MB/s eta 0:00:02
#      -- ------------------------------------- 2.7/42.2 MB 18.7 MB/s eta 0:00:03
#      --- ------------------------------------ 3.8/42.2 MB 20.0 MB/s eta 0:00:02
#      ---- ----------------------------------- 4.9/42.2 MB 20.7 MB/s eta 0:00:02
#      ----- ---------------------------------- 6.1/42.2 MB 21.5 MB/s eta 0:00:02
#      ------ --------------------------------- 6.8/42.2 MB 20.8 MB/s eta 0:00:02
#      ------- -------------------------------- 8.0/42.2 MB 22.2 MB/s eta 0:00:02
#      -------- ------------------------------- 9.0/42.2 MB 21.3 MB/s eta 0:00:02
#      --------- ----------------------------- 10.1/42.2 MB 21.5 MB/s eta 0:00:02
#      ---------- ---------------------------- 11.1/42.2 MB 21.8 MB/s eta 0:00:02
#      ---------- ---------------------------- 11.9/42.2 MB 21.8 MB/s eta 0:00:02
#      ------------ -------------------------- 13.1/42.2 MB 22.6 MB/s eta 0:00:02
#      ------------ -------------------------- 13.8/42.2 MB 21.8 MB/s eta 0:00:02
#      ------------- ------------------------- 14.5/42.2 MB 21.1 MB/s eta 0:00:02
#      -------------- ------------------------ 15.6/42.2 MB 20.5 MB/s eta 0:00:02
#      --------------- ----------------------- 16.3/42.2 MB 20.5 MB/s eta 0:00:02
#      --------------- ----------------------- 17.2/42.2 MB 20.5 MB/s eta 0:00:02
#      ---------------- ---------------------- 17.8/42.2 MB 19.3 MB/s eta 0:00:02
#      ----------------- --------------------- 18.4/42.2 MB 18.7 MB/s eta 0:00:02
#      ----------------- --------------------- 19.5/42.2 MB 18.7 MB/s eta 0:00:02
#      ------------------ -------------------- 20.4/42.2 MB 18.7 MB/s eta 0:00:02
#      ------------------- ------------------- 20.7/42.2 MB 17.7 MB/s eta 0:00:02
#      -------------------- ------------------ 21.9/42.2 MB 18.2 MB/s eta 0:00:02
#      -------------------- ------------------ 22.6/42.2 MB 17.7 MB/s eta 0:00:02
#      --------------------- ----------------- 23.4/42.2 MB 16.8 MB/s eta 0:00:02
#      --------------------- ----------------- 23.6/42.2 MB 16.4 MB/s eta 0:00:02
#      ---------------------- ---------------- 24.1/42.2 MB 16.0 MB/s eta 0:00:02
#      ---------------------- ---------------- 24.8/42.2 MB 16.0 MB/s eta 0:00:02
#      ----------------------- --------------- 25.8/42.2 MB 15.2 MB/s eta 0:00:02
#      ------------------------ -------------- 26.5/42.2 MB 15.6 MB/s eta 0:00:02
#      ------------------------- ------------- 27.4/42.2 MB 15.2 MB/s eta 0:00:01
#      ------------------------- ------------- 28.1/42.2 MB 16.0 MB/s eta 0:00:01
#      -------------------------- ------------ 28.9/42.2 MB 15.6 MB/s eta 0:00:01
#      --------------------------- ----------- 29.5/42.2 MB 15.6 MB/s eta 0:00:01
#      ---------------------------- ---------- 30.3/42.2 MB 14.9 MB/s eta 0:00:01
#      ---------------------------- ---------- 31.1/42.2 MB 15.6 MB/s eta 0:00:01
#      ----------------------------- --------- 31.8/42.2 MB 15.2 MB/s eta 0:00:01
#      ------------------------------ -------- 32.5/42.2 MB 14.9 MB/s eta 0:00:01
#      ------------------------------ -------- 33.4/42.2 MB 15.2 MB/s eta 0:00:01
#      ------------------------------- ------- 34.2/42.2 MB 16.4 MB/s eta 0:00:01
#      -------------------------------- ------ 35.1/42.2 MB 16.8 MB/s eta 0:00:01
#      --------------------------------- ----- 35.8/42.2 MB 16.8 MB/s eta 0:00:01
#      --------------------------------- ----- 36.7/42.2 MB 16.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 37.4/42.2 MB 16.4 MB/s eta 0:00:01
#      ----------------------------------- --- 38.3/42.2 MB 17.2 MB/s eta 0:00:01
#      ------------------------------------ -- 39.3/42.2 MB 16.8 MB/s eta 0:00:01
#      ------------------------------------- - 40.2/42.2 MB 17.7 MB/s eta 0:00:01
#      ------------------------------------- - 41.1/42.2 MB 17.7 MB/s eta 0:00:01
#      --------------------------------------  42.0/42.2 MB 18.2 MB/s eta 0:00:01
#      --------------------------------------  42.2/42.2 MB 18.2 MB/s eta 0:00:01
#      --------------------------------------  42.2/42.2 MB 18.2 MB/s eta 0:00:01
#      --------------------------------------  42.2/42.2 MB 18.2 MB/s eta 0:00:01
#      --------------------------------------- 42.2/42.2 MB 12.8 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.3.3-py3-none-any.whl (242 kB)
#      ---------------------------------------- 0.0/242.3 kB ? eta -:--:--
#      ------------------------------------- 242.3/242.3 kB 14.5 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.0-py3-none-any.whl (2.4 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.29.0)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
#      ---------------------------------------- 0.0/178.2 kB ? eta -:--:--
#      ------------------------------------- 178.2/178.2 kB 11.2 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.3 kB ? eta -:--:--
#      ---------------------------------------- 181.3/181.3 kB ? eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.11.0)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ---------------------------------------- 0.0/83.9 kB ? eta -:--:--
#      ---------------------------------------- 83.9/83.9 kB 4.6 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml): started
#   Building wheel for jax (pyproject.toml): finished with status 'done'
#   Created wheel for jax: filename=jax-0.4.8-py3-none-any.whl size=1439795 sha256=33ed119da4d936c71c20f1daf3fc543e6aae4cd3abe6b16b4039607c2a0278fe
#   Stored in directory: c:\users\jeetp\appdata\local\pip\cache\wheels\45\83\1e\3db22c5e1941c10e41c4f5cdf829b0a358146d4d0733d4a105
# Successfully built jax
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, scipy, rsa, requests-oauthlib, pyasn1-modules, opt-einsum, ml-dtypes, markdown, h5py, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\jeetp\\anaconda3\\envs\\myenv\\Lib\\site-packages\\~umpy\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.

# %%
pip install Flask
# Out:
# Collecting Flask
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from Flask) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.3.3 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from Flask) (2.3.3)
# Collecting click>=8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.6 kB ? eta -:--:--
#      ---------------------------------------- 96.6/96.6 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from Flask) (6.0.0)
# Requirement already satisfied: colorama in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata>=3.6.0->Flask) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from Jinja2>=3.1.2->Flask) (2.1.1)
# Installing collected packages: itsdangerous, click, blinker, Flask
# Successfully installed Flask-2.3.2 blinker-1.6.2 click-8.1.3 itsdangerous-2.1.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script flask.exe is installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install Werkzeug
# Out:
# Requirement already satisfied: Werkzeug in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (2.3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from Werkzeug) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gunicorn
# Out:
# Collecting gunicorn
#   Using cached gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: setuptools>=3.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from gunicorn) (66.0.0)
# Installing collected packages: gunicorn
# Successfully installed gunicorn-20.1.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script gunicorn.exe is installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# Collecting comtypes
#   Downloading comtypes-1.1.14-py2.py3-none-any.whl (172 kB)
#      ---------------------------------------- 0.0/172.8 kB ? eta -:--:--
#      ------------------------ ------------- 112.6/172.8 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 172.8/172.8 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: pywin32 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from pyttsx3) (305.1)
# Collecting pypiwin32
#   Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: comtypes, pypiwin32, pyttsx3
# Successfully installed comtypes-1.1.14 pypiwin32-223 pyttsx3-2.90
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp38-cp38-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#       --------------------------------------- 0.2/7.6 MB 4.5 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/7.6 MB 8.5 MB/s eta 0:00:01
#      ----------- ---------------------------- 2.1/7.6 MB 19.3 MB/s eta 0:00:01
#      -------------------- ------------------- 4.0/7.6 MB 23.2 MB/s eta 0:00:01
#      --------------------------------- ------ 6.3/7.6 MB 30.9 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.6 MB 28.3 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 25.7 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (5.2.0)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp38-cp38-win_amd64.whl (55 kB)
#      ---------------------------------------- 0.0/55.4 kB ? eta -:--:--
#      ---------------------------------------- 55.4/55.4 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (23.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 0.0/98.3 kB ? eta -:--:--
#      ---------------------------------------- 98.3/98.3 kB ? eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ---------------------------------------- 1.0/1.0 MB 66.6 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-win_amd64.whl (162 kB)
#      ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#      -------------------------------------- 163.0/163.0 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.23.5)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp38-cp38-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      -------------------------------- ------- 2.1/2.5 MB 43.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 40.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.3 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.0.1-cp38-cp38-win_amd64.whl (10.8 MB)
#      ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#       --------------------------------------- 0.2/10.8 MB 4.9 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.2/10.8 MB 13.1 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.1/10.8 MB 22.4 MB/s eta 0:00:01
#      ---------------- ----------------------- 4.4/10.8 MB 23.3 MB/s eta 0:00:01
#      -------------------------- ------------- 7.3/10.8 MB 31.0 MB/s eta 0:00:01
#      ------------------------------ --------- 8.1/10.8 MB 30.6 MB/s eta 0:00:01
#      ------------------------------------ -- 10.0/10.8 MB 31.9 MB/s eta 0:00:01
#      --------------------------------------  10.8/10.8 MB 36.4 MB/s eta 0:00:01
#      --------------------------------------- 10.8/10.8 MB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.3 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from pandas) (1.23.5)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ---------------------------------------- 341.8/341.8 kB ? eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.0.1 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp38-cp38-win_amd64.whl (272.8 MB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.4)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.8-py3-none-any.whl
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.8.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.54.0-cp38-cp38-win_amd64.whl (4.1 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.5.0)
# Requirement already satisfied: setuptools in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (66.0.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: packaging in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Collecting scipy>=1.7
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Collecting ml-dtypes>=0.0.3
#   Using cached ml_dtypes-0.1.0-cp38-cp38-win_amd64.whl (120 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.29.0)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (6.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Installing collected packages: scipy, rsa, pyasn1-modules, opt-einsum, ml-dtypes, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, markdown, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 gast-0.4.0 google-auth-2.17.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.0 h5py-3.8.0 jax-0.4.8 markdown-3.4.3 ml-dtypes-0.1.0 opt-einsum-3.3.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 scipy-1.10.1 tensorboard-2.12.3 tensorflow-2.12.0 tensorflow-intel-2.12.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool.exe is installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\jeetp\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install -U scikit-learn
# Out:
# Collecting scikit-learnNote: you may need to restart the kernel to use updated packages.
#
#   Downloading scikit_learn-1.2.2-cp38-cp38-win_amd64.whl (8.3 MB)
#      ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#      - -------------------------------------- 0.3/8.3 MB 6.3 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.0/8.3 MB 11.0 MB/s eta 0:00:01
#      ------------ --------------------------- 2.6/8.3 MB 18.5 MB/s eta 0:00:01
#      ---------------------- ----------------- 4.6/8.3 MB 24.4 MB/s eta 0:00:01
#      ------------------------------ --------- 6.3/8.3 MB 28.6 MB/s eta 0:00:01
#      ------------------------------------ --- 7.7/8.3 MB 28.8 MB/s eta 0:00:01
#      -------------------------------------- - 8.0/8.3 MB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 23.0 MB/s eta 0:00:01
#      ---------------------------------------- 8.3/8.3 MB 21.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\jeetp\anaconda3\envs\myenv\lib\site-packages (from scikit-learn) (1.10.1)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ---------------------------------------- 0.0/298.0 kB ? eta -:--:--
#      ------------------------------------- 298.0/298.0 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2 threadpoolctl-3.1.0

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
#import cv2
import tensorflow as tf
from PIL import Image
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
import os
os.chdir('C:/Users/jeetp/gtsrb-preprocessed')
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

# %%
data = []
labels = []
# We have 43 Classes
classes = 44
cur_path = os.getcwd()

# %%
cur_path
# Out:
# 'C:\\Users\\jeetp\\gtsrb-preprocessed'

# %%
for i in range(classes-1):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)
    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            data.append(image)
            labels.append(i)
        except Exception as e:
            print(e)

# %%
data = np.array(data)
labels = np.array(labels)

# %%
import os

# Check if the directory exists, if not, create it
if not os.path.exists('../training'):
    os.mkdir('../training')

np.save('../training/data', data)
np.save('../training/target', labels)

# %%
# os.mkdir('training')

np.save('../training/data',data)
np.save('../training/target',labels)

# %%
data=np.load('../training/data.npy')
labels=np.load('../training/target.npy')

# %%
print(data.shape, labels.shape)
# Out:
# (39209, 30, 30, 3) (39209,)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (31367, 30, 30, 3) (7842, 30, 30, 3) (31367,) (7842,)

# %%
y_train = to_categorical(y_train, 44)
y_test = to_categorical(y_test, 44)

# %%
# Adding EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Using ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,  
    zoom_range = 0.1, 
    width_shift_range=0.1, 
    height_shift_range=0.1)

# Fit the data generator on your training data
datagen.fit(X_train)

# %%
# Add BatchNormalization layers to your model
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(44, activation='softmax'))

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))


model.add(Dense(44, activation='softmax'))

# %%
#Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model using the data generator
history = model.fit(datagen.flow(X_train, y_train, batch_size=32),
                    epochs=15, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/15
# 981/981 [==============================] - 53s 52ms/step - loss: 1.5319 - accuracy: 0.5742 - val_loss: 0.1471 - val_accuracy: 0.9566
# Epoch 2/15
# 981/981 [==============================] - 51s 52ms/step - loss: 0.4095 - accuracy: 0.8751 - val_loss: 0.0451 - val_accuracy: 0.9880
# Epoch 3/15
# 981/981 [==============================] - 52s 53ms/step - loss: 0.2370 - accuracy: 0.9285 - val_loss: 0.0527 - val_accuracy: 0.9855
# Epoch 4/15
# 981/981 [==============================] - 53s 54ms/step - loss: 0.1956 - accuracy: 0.9418 - val_loss: 0.0274 - val_accuracy: 0.9946
# Epoch 5/15
# 981/981 [==============================] - 55s 56ms/step - loss: 0.1539 - accuracy: 0.9545 - val_loss: 0.0290 - val_accuracy: 0.9932
# Epoch 6/15
# 981/981 [==============================] - 51s 52ms/step - loss: 0.1311 - accuracy: 0.9616 - val_loss: 0.0279 - val_accuracy: 0.9935
# Epoch 7/15
# 981/981 [==============================] - 52s 53ms/step - loss: 0.1232 - accuracy: 0.9650 - val_loss: 0.0253 - val_accuracy: 0.9943
# Epoch 8/15
# 981/981 [==============================] - 53s 54ms/step - loss: 0.1151 - accuracy: 0.9662 - val_loss: 0.0200 - val_accuracy: 0.9958
# Epoch 9/15
# 981/981 [==============================] - 52s 53ms/step - loss: 0.0993 - accuracy: 0.9722 - val_loss: 0.0141 - val_accuracy: 0.9972
# Epoch 10/15
# 981/981 [==============================] - 53s 54ms/step - loss: 0.0892 - accuracy: 0.9742 - val_loss: 0.0167 - val_accuracy: 0.9962
# Epoch 11/15
# 981/981 [==============================] - 53s 54ms/step - loss: 0.0957 - accuracy: 0.9723 - val_loss: 0.0216 - val_accuracy: 0.9950
# Epoch 12/15
# 981/981 [==============================] - 52s 53ms/step - loss: 0.0856 - accuracy: 0.9757 - val_loss: 0.0165 - val_accuracy: 0.9955

# %%
epochs = 15
history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))
# Out:
# Epoch 1/15
# 1961/1961 [==============================] - 98s 49ms/step - loss: 1.1361 - accuracy: 0.7143 - val_loss: 0.1379 - val_accuracy: 0.9685
# Epoch 2/15
# 1961/1961 [==============================] - 102s 52ms/step - loss: 0.2907 - accuracy: 0.9209 - val_loss: 0.0777 - val_accuracy: 0.9797
# Epoch 3/15
# 1961/1961 [==============================] - 103s 52ms/step - loss: 0.2191 - accuracy: 0.9394 - val_loss: 0.0921 - val_accuracy: 0.9730
# Epoch 4/15
# 1961/1961 [==============================] - 110s 56ms/step - loss: 0.1895 - accuracy: 0.9501 - val_loss: 0.0829 - val_accuracy: 0.9777
# Epoch 5/15
# 1961/1961 [==============================] - 107s 54ms/step - loss: 0.1775 - accuracy: 0.9527 - val_loss: 0.0423 - val_accuracy: 0.9872
# Epoch 6/15
# 1961/1961 [==============================] - 88s 45ms/step - loss: 0.1791 - accuracy: 0.9540 - val_loss: 0.0415 - val_accuracy: 0.9894
# Epoch 7/15
# 1961/1961 [==============================] - 88s 45ms/step - loss: 0.1638 - accuracy: 0.9591 - val_loss: 0.0496 - val_accuracy: 0.9848
# Epoch 8/15
# 1961/1961 [==============================] - 88s 45ms/step - loss: 0.1598 - accuracy: 0.9605 - val_loss: 0.0346 - val_accuracy: 0.9900
# Epoch 9/15
# 1961/1961 [==============================] - 89s 45ms/step - loss: 0.1670 - accuracy: 0.9605 - val_loss: 0.0377 - val_accuracy: 0.9889
# Epoch 10/15
# 1961/1961 [==============================] - 91s 47ms/step - loss: 0.1557 - accuracy: 0.9630 - val_loss: 0.0307 - val_accuracy: 0.9918
# Epoch 11/15
# 1961/1961 [==============================] - 91s 46ms/step - loss: 0.1730 - accuracy: 0.9586 - val_loss: 0.0373 - val_accuracy: 0.9906
# Epoch 12/15
# 1961/1961 [==============================] - 90s 46ms/step - loss: 0.1655 - accuracy: 0.9603 - val_loss: 0.0226 - val_accuracy: 0.9937
# Epoch 13/15
# 1961/1961 [==============================] - 89s 45ms/step - loss: 0.1698 - accuracy: 0.9607 - val_loss: 0.0270 - val_accuracy: 0.9919
# Epoch 14/15
# 1961/1961 [==============================] - 88s 45ms/step - loss: 0.1774 - accuracy: 0.9604 - val_loss: 0.0299 - val_accuracy: 0.9916
# Epoch 15/15
# 1961/1961 [==============================] - 88s 45ms/step - loss: 0.1852 - accuracy: 0.9584 - val_loss: 0.0293 - val_accuracy: 0.9912

# %%
model.save('../training/new.traffics.h5')

# %%
# accuracy 
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# Loss
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Test loss: 0.016525112092494965
# Test accuracy: 0.9955368638038635

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        2432
#
#  batch_normalization (BatchN  (None, 26, 26, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 22, 22, 32)        25632
#
#  batch_normalization_1 (Batc  (None, 22, 22, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 11, 11, 32)       0
#  )
#
#  dropout (Dropout)           (None, 11, 11, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 64)          18496
#
#  batch_normalization_2 (Batc  (None, 9, 9, 64)         256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 3, 3, 64)          0
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 256)               147712
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 44)                11308
#
# =================================================================
# Total params: 243,276
# Trainable params: 242,892
# Non-trainable params: 384
# _________________________________________________________________

# %%
import numpy as np

# %%
# Classes of trafic signs
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons',
            43: 'No sign'}

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
def test_on_img(img):
    data=[]
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))
    X_test=np.array(data)
    Y_pred = model.predict_classes(X_test)
    return image,Y_pred

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load and preprocess the image
img = image.load_img(r'C:\Users\jeetp\gtsrb-preprocessed\train\14\00014_00006_00029.png', target_size=(30, 30))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)

# Predict the class probabilities
probabilities = model.predict(img)

# Get the index with the highest probability
predicted_class = np.argmax(probabilities)

print("Predicted traffic sign is: ", classes[predicted_class])
plt.imshow(image.load_img(r'C:\Users\jeetp\gtsrb-preprocessed\train\14\00014_00006_00029.png'))
plt.show()
# Out:
# 1/1 [==============================] - 0s 112ms/step
# Predicted traffic sign is:  Stop
